# %% [markdown]
# # Working with APIs
#
#
#
# Lesson Goals
#
#     Understand what is API and what it does.
#     Learn how to make simple calls to an API and retrieve JSON data.
#     Learn how to handle nested JSON API results.
#
# Introduction
#
# Thus far in the program, we have learned how to obtain data from files and from relational databases. However, sometimes the data we need is not readily available via one of these two data sources. In some cases, the data we need may be contained within an application. Application owners will often create APIs (or Application Programming Interface) so that their applications can talk to other applications. An API is a set of programmatic instructions for accessing software applications, and the data that comes from APIs typically contains some sort of structure (such as JSON). This structure makes working with API data preferable to crawling websites and scraping content off of web pages.
#
# In this lesson, we are going to learn how to make API calls to an application, retrieve data in JSON format, learn about API authentication, and use Python libraries to obtain data from APIs.
# Simple API Example with Requests
#
# There are a few libraries that can be used for working with APIs in Python, but the Requests library is one of the most intuitive. It has a get method that allows you to send an HTTP request to an application and receive a response. Let's take a look at a basic API call using the requests library.

# %%
import json
import requests

response = requests.get('https://jsonplaceholder.typicode.com/todos')
results = response.json()
results[0]
# Out:
# {'userId': 1, 'id': 1, 'title': 'delectus aut autem', 'completed': False}

# %% [markdown]
# In this example, we used the get method to send a request to the JSONPlaceholder API, and we received back a response in the form of JSON structured data. If we wanted to analyze this data, we could easily use Pandas to convert the results into a data frame to which we can then apply various analytical methods.

# %%
import pandas as pd

data = pd.DataFrame(results)
data.head()
# Out:
#    userId  id                                              title  completed
# 0       1   1                                 delectus aut autem      False
# 1       1   2                 quis ut nam facilis et officia qui      False
# 2       1   3                                fugiat veniam minus      False
# 3       1   4                                   et porro tempora       True
# 4       1   5  laboriosam mollitia et enim quasi adipisci qui...      False

# %% [markdown]
# # More Complex Requests API Example
#
# In the previous section, the data we received from the API was not very complex. It was all at a single level and fit neatly into a data frame. However, sometimes API responses contain data that is nested, and we must find a way to flatten the JSON data so that it fits nicely into a data frame. Let's make an API call to the Github public API, create a Pandas data frame from the results, and examine the structure of the data.

# %%
response = requests.get('https://api.github.com/events')

data = pd.DataFrame(response.json())
data.head()
# Out:
#             id               type  \
# 0  16391587527          PushEvent
# 1  16391587547          PushEvent
# 2  16391587501          PushEvent
# 3  16391587487  IssueCommentEvent
# 4  16391587503          PushEvent
#
#                                                actor  \
# 0  {'id': 5524384, 'login': 'joeldenning', 'displ...
# 1  {'id': 81362359, 'login': 'marie-projet', 'dis...
# 2  {'id': 16430046, 'login': 'ruslan-avantis', 'd...
# 3  {'id': 49699333, 'login': 'dependabot[bot]', '...
# 4  {'id': 81343882, 'login': 'kyl3ru1z', 'display...
#
#                                                 repo  \
# 0  {'id': 48821599, 'name': 'single-spa/import-ma...
# 1  {'id': 358613817, 'name': 'marie-projet/Projet...
# 2  {'id': 359625878, 'name': 'ruslan-avantis/rusl...
# 3  {'id': 262583218, 'name': 'vpvnguyen/jwt-refer...
# 4  {'id': 368013977, 'name': 'kyl3ru1z/Calculator...
#
#                                              payload  public  \
# 0  {'push_id': 7132845865, 'size': 1, 'distinct_s...    True
# 1  {'push_id': 7132845873, 'size': 1, 'distinct_s...    True
# 2  {'push_id': 7132845851, 'size': 1, 'distinct_s...    True
# 3  {'action': 'created', 'issue': {'url': 'https:...    True
# 4  {'push_id': 7132845861, 'size': 1, 'distinct_s...    True
#
#              created_at                                                org
# 0  2021-05-17T16:47:21Z  {'id': 59940233, 'login': 'single-spa', 'grava...
# 1  2021-05-17T16:47:21Z                                                NaN
# 2  2021-05-17T16:47:21Z                                                NaN
# 3  2021-05-17T16:47:21Z                                                NaN
# 4  2021-05-17T16:47:21Z                                                NaN

# %% [markdown]
# When we look at the data frame, we can see that there are dictionaries nested in several fields. We need to extract the information that is in these fields and add them to the data frame as columns. To do this, we are going to create our own flatten function that accepts a data frame and a list of columns that contain nested dictionaries in them. Our function is going to iterate through the columns and, for each column, it is going to:
#
#     Turn the nested dictionaries into a data frame with a column for each key
#     Assign column names to each column in this new data frame
#     Add these new columns to the original data frame
#     Drop the column with the nested dictionaries

# %%
def flatten(data, col_list):
    for column in col_list:
        flattened = pd.DataFrame(dict(data[column])).transpose()
        columns = [str(col) for col in flattened.columns]
        flattened.columns = [column + '_' + colname for colname in columns]
        data = pd.concat([data, flattened], axis=1)
        data = data.drop(column, axis=1)
    return data

# %% [markdown]
# Now that we have our function, let's apply it to the columns that have nested dictionaries and get back a revised data frame.

# %%
nested_columns = ['actor', 'org', 'payload', 'repo']

flat = flatten(data, nested_columns)
flat.head()
# Out:
#             id               type  public            created_at  actor_id  \
# 0  16391587527          PushEvent    True  2021-05-17T16:47:21Z   5524384
# 1  16391587547          PushEvent    True  2021-05-17T16:47:21Z  81362359
# 2  16391587501          PushEvent    True  2021-05-17T16:47:21Z  16430046
# 3  16391587487  IssueCommentEvent    True  2021-05-17T16:47:21Z  49699333
# 4  16391587503          PushEvent    True  2021-05-17T16:47:21Z  81343882
#
#        actor_login actor_display_login actor_gravatar_id  \
# 0      joeldenning         joeldenning
# 1     marie-projet        marie-projet
# 2   ruslan-avantis      ruslan-avantis
# 3  dependabot[bot]          dependabot
# 4         kyl3ru1z            kyl3ru1z
#
#                                       actor_url  \
# 0      https://api.github.com/users/joeldenning
# 1     https://api.github.com/users/marie-projet
# 2   https://api.github.com/users/ruslan-avantis
# 3  https://api.github.com/users/dependabot[bot]
# 4         https://api.github.com/users/kyl3ru1z
#
#                                     actor_avatar_url  ... payload_review  \
# 0   https://avatars.githubusercontent.com/u/5524384?  ...            NaN
# 1  https://avatars.githubusercontent.com/u/81362359?  ...            NaN
# 2  https://avatars.githubusercontent.com/u/16430046?  ...            NaN
# 3  https://avatars.githubusercontent.com/u/49699333?  ...            NaN
# 4  https://avatars.githubusercontent.com/u/81343882?  ...            NaN
#
#   payload_pull_request payload_number payload_ref_type payload_master_branch  \
# 0                  NaN            NaN              NaN                   NaN
# 1                  NaN            NaN              NaN                   NaN
# 2                  NaN            NaN              NaN                   NaN
# 3                  NaN            NaN              NaN                   NaN
# 4                  NaN            NaN              NaN                   NaN
#
#   payload_description payload_pusher_type    repo_id  \
# 0                 NaN                 NaN   48821599
# 1                 NaN                 NaN  358613817
# 2                 NaN                 NaN  359625878
# 3                 NaN                 NaN  262583218
# 4                 NaN                 NaN  368013977
#
#                         repo_name  \
# 0  single-spa/import-map-deployer
# 1     marie-projet/ProjetTreillis
# 2   ruslan-avantis/ruslan-avantis
# 3         vpvnguyen/jwt-reference
# 4          kyl3ru1z/CalculatorApp
#
#                                             repo_url
# 0  https://api.github.com/repos/single-spa/import...
# 1  https://api.github.com/repos/marie-projet/Proj...
# 2  https://api.github.com/repos/ruslan-avantis/ru...
# 3  https://api.github.com/repos/vpvnguyen/jwt-ref...
# 4  https://api.github.com/repos/kyl3ru1z/Calculat...
#
# [5 rows x 35 columns]

# %% [markdown]
# Alternatively, we can flatten nested data using the function json_normalize. This function is part of the Pandas library. The function will flatten and rename each flattened column to the name of the original column and the name of the nested column separated by a period. For example actor.avatar_url.
#
# Here is an example of how to use this function. Note that you have to import it separately in order to avoid using the full path when calling the function.

# %%
from pandas.io.json import json_normalize

results = response.json()
flattened_data = json_normalize(results)

flattened_data.head()
# Out:
# <ipython-input-6-f52dd4c64a36>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
#             id               type  public            created_at  actor.id  \
# 0  16391587527          PushEvent    True  2021-05-17T16:47:21Z   5524384
# 1  16391587547          PushEvent    True  2021-05-17T16:47:21Z  81362359
# 2  16391587501          PushEvent    True  2021-05-17T16:47:21Z  16430046
# 3  16391587487  IssueCommentEvent    True  2021-05-17T16:47:21Z  49699333
# 4  16391587503          PushEvent    True  2021-05-17T16:47:21Z  81343882
#
#        actor.login actor.display_login actor.gravatar_id  \
# 0      joeldenning         joeldenning
# 1     marie-projet        marie-projet
# 2   ruslan-avantis      ruslan-avantis
# 3  dependabot[bot]          dependabot
# 4         kyl3ru1z            kyl3ru1z
#
#                                       actor.url  \
# 0      https://api.github.com/users/joeldenning
# 1     https://api.github.com/users/marie-projet
# 2   https://api.github.com/users/ruslan-avantis
# 3  https://api.github.com/users/dependabot[bot]
# 4         https://api.github.com/users/kyl3ru1z
#
#                                     actor.avatar_url  ...  \
# 0   https://avatars.githubusercontent.com/u/5524384?  ...
# 1  https://avatars.githubusercontent.com/u/81362359?  ...
# 2  https://avatars.githubusercontent.com/u/16430046?  ...
# 3  https://avatars.githubusercontent.com/u/49699333?  ...
# 4  https://avatars.githubusercontent.com/u/81343882?  ...
#
#    payload.issue.assignee.organizations_url payload.issue.assignee.repos_url  \
# 0                                       NaN                              NaN
# 1                                       NaN                              NaN
# 2                                       NaN                              NaN
# 3                                       NaN                              NaN
# 4                                       NaN                              NaN
#
#   payload.issue.assignee.events_url  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
#
#    payload.issue.assignee.received_events_url  payload.issue.assignee.type  \
# 0                                         NaN                          NaN
# 1                                         NaN                          NaN
# 2                                         NaN                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#    payload.issue.assignee.site_admin payload.ref_type payload.master_branch  \
# 0                                NaN              NaN                   NaN
# 1                                NaN              NaN                   NaN
# 2                                NaN              NaN                   NaN
# 3                                NaN              NaN                   NaN
# 4                                NaN              NaN                   NaN
#
#   payload.description payload.pusher_type
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN
#
# [5 rows x 488 columns]

# %% [markdown]
# Looks much cleaner, and now we have access to the information that was enclosed within those dictionaries. Sometimes multiple rounds of flattening will be required if the JSON data returned from the API you are working with has hierarchically nested data.
